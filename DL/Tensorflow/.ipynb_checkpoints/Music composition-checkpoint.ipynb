# %%
import numpy as np
import tensorflow as tf
from music21 import note, chord, stream, duration
import random

# Step 1: Generate Simple Notes/Chords with Duration
def get_notes_with_durations():
    base_notes = [
        note.Note('C4'), note.Note('E4'), note.Note('G4'), note.Note('C5'),
        chord.Chord(['C4', 'E4', 'G4']), chord.Chord(['F4', 'A4', 'C5']),
        note.Note('D4'), note.Note('F4'), note.Note('A4')
    ]
    durations = [0.25, 0.5, 1.0]  # quarter, half, whole

    notes_with_durations = []
    for n in base_notes:
        d = random.choice(durations)
        n.duration = duration.Duration(d)
        notes_with_durations.append(n)
    return notes_with_durations

def note_to_string(n):
    if isinstance(n, note.Note):
        return f"{n.nameWithOctave}_{n.duration.quarterLength}"
    elif isinstance(n, chord.Chord):
        chord_str = '.'.join(p.nameWithOctave for p in n.pitches)
        return f"{chord_str}_{n.duration.quarterLength}"
    return str(n)

def prepare_sequences(notes, sequence_length=4):
    return [notes[i:i + sequence_length] for i in range(len(notes) - sequence_length)]

# Load notes and convert
notes = get_notes_with_durations()
note_strings = [note_to_string(n) for n in notes]
sequence_input = prepare_sequences(note_strings)

# Create mappings
unique_notes = sorted(set(note_strings))
note_to_int = {n: i for i, n in enumerate(unique_notes)}
int_to_note = {i: n for n, i in note_to_int.items()}

# Convert to integer sequences
X = np.array([[note_to_int[n] for n in seq] for seq in sequence_input])
y = np.array([note_to_int[note_strings[i + 4]] for i in range(len(note_strings) - 4)])
X = X.reshape((X.shape[0], X.shape[1], 1))

# LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, input_shape=(X.shape[1], X.shape[2]), return_sequences=True),
    tf.keras.layers.LSTM(128),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(len(unique_notes), activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.fit(X, y, epochs=100, batch_size=1, verbose=1)

# Music generation with duration decoding
def generate_music(model, note_to_int, int_to_note, seed_sequence, n_notes=50):
    prediction_input = list(seed_sequence)
    predictions = []

    for _ in range(n_notes):
        input_seq = np.reshape(prediction_input, (1, len(prediction_input), 1))
        pred = model.predict(input_seq, verbose=0)
        index = np.argmax(pred)
        predictions.append(index)
        prediction_input.append(index)
        prediction_input = prediction_input[1:]

    predicted_strings = [int_to_note.get(i) for i in predictions]
    print(f"Predicted notes: {predicted_strings}")

    predicted_stream = stream.Stream()
    for note_string in predicted_strings:
        try:
            if note_string is None:
                continue
            pitch_part, duration_part = note_string.rsplit('_', 1)
            dur = float(duration_part)
            if '.' in pitch_part:
                chord_notes = [note.Note(n) for n in pitch_part.split('.')]
                for n in chord_notes:
                    n.duration = duration.Duration(dur)
                predicted_stream.append(chord.Chord(chord_notes))
            else:
                n = note.Note(pitch_part)
                n.duration = duration.Duration(dur)
                predicted_stream.append(n)
        except Exception as e:
            print(f"Error with note '{note_string}': {e}")

    midi_file_path = 'generated_music_with_durations.mid'
    predicted_stream.write('midi', fp=midi_file_path)
    print(f"Music with durations saved to: {midi_file_path}")
    return predicted_strings

# Generate music
seed_sequence = ['C4_1.0', 'E4_0.5', 'G4_0.25', 'C5_1.0']
for n in seed_sequence:
    if n not in note_to_int:
        idx = len(note_to_int)
        note_to_int[n] = idx
        int_to_note[idx] = n

seed_sequence_int = [note_to_int[n] for n in seed_sequence]
predicted_notes = generate_music(model, note_to_int, int_to_note, seed_sequence_int)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.2094
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1260
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0544
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9933
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9101
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8274
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6404
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6046
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6611
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5071
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6676
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5849
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4649
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5807
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3749
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5615
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3265
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4016
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0695
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2820
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9419
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8194
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0930
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8350
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8158
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7193
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8567
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5986
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6359
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6379
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2963
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5355
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3254
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3289
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2333
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1923
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4662
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2427
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2390
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3421
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2560
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2486
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2381
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1243
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1480
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0838
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0691
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0436
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0419
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0690
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0500
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0400
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0481
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0355
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0342
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0295
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0228
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0235
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0210
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0143
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0133
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0156
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0113
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0102
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0116
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0124
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0121
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0083
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0097
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0084
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0084
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0081
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0049
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0061
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0057
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0033
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031
# Predicted notes: ['C4.E4.G4_0.5', 'F4.A4.C5_0.25', 'D4_1.0', 'F4_0.25', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'D4_1.0', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'F4_0.25', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'D4_1.0', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'F4_0.25', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'D4_1.0', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'F4_0.25', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'D4_1.0', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'F4_0.25', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'D4_1.0', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'F4_0.25', 'A4_1.0', 'F4.A4.C5_0.25', 'D4_1.0', 'D4_1.0', 'A4_1.0', 'F4.A4.C5_0.25']
# Music with durations saved to: generated_music_with_durations.mid
