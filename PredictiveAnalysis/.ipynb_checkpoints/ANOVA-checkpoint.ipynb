# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Set a seed for reproducibility
np.random.seed(42)

# Generate random data for 3 groups with different means
group1 = np.random.normal(loc=70, scale=5, size=30)
group2 = np.random.normal(loc=75, scale=5, size=30)
group3 = np.random.normal(loc=80, scale=5, size=30)

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(group1, group2, group3)

print("F-statistic:", f_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("There is a significant difference between groups.")
else:
    print("No significant difference between groups.")

# Create a boxplot
plt.figure(figsize=(8, 5))
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])
plt.title('Test Scores by Group')
plt.ylabel('Score')
plt.grid(True)
plt.show()
# Out:
# F-statistic: 40.97563597701796
# P-value: 2.89376813507174e-13
# There is a significant difference between groups.
# C:\Users\KRISHNENDU\AppData\Local\Temp\ipykernel_20760\563371058.py:25: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])
